# %% [markdown]
# <a href="https://colab.research.google.com/github/ChungbinKim/-/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

path = "data.csv"
data = np.genfromtxt(path, delimiter=',')

# 2D->1D로 바꿈
x_data = data[:, [0]]
y_data = data[:, 1]


# linear regression
model = LinearRegression()

model.fit(x_data, y_data)

# x,y값 찾기
x_new = np.linspace(-10,10)
y_new = model.predict(x_new[:, np.newaxis])

#과제 3-1
plt.figure(figsize=(8, 8))
plt.scatter(x_data, y_data, alpha=0.3, c='black')
#과제 3-2
plt.plot(x_new, y_new,'r')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

path = "data.csv"
data = np.genfromtxt(path, delimiter=',')

x_data = data[:, 0]
y_data = data[:, 1]




plt.figure(figsize=(8, 8))
plt.scatter(x_data, y_data, alpha=0.3, c='black')
plt.show()
