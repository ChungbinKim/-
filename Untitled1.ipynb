# %% [markdown]
# <a href="https://colab.research.google.com/github/ChungbinKim/-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from random import randint

# x값=0~20,x값을 100개 잡기
x = 20 * np.random.random((100, 1))

# y=2*x+1그리기,y=2*x+1 위아래에 점찍기,잘보이기 위해 random.normal에 10을곱함

y=2*x+1+ 10*np.random.normal(size=x.shape)


# linear regression
model = LinearRegression()
model.fit(x, y)

# x,y값 찾기
x_new = np.linspace(0,20)
y_new = model.predict(x_new[:, np.newaxis])

# 새 표 그리기,새 값 찾기
plt.figure(figsize=(10, 5))
new = plt.axes()

#과제 2-1
plt.plot(x,2*x+1,'b')
new.scatter(x, y,c='black')
#과제 2-2
new.plot(x_new, y_new,'r')

new.set_xlabel('x')
new.set_ylabel('y')
plt.title("linear regression")
plt.show()
