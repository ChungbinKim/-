# %% [markdown]
# <a href="https://colab.research.google.com/github/ChungbinKim/-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from random import randint
x=np.arange(-20.00,20.00,1)

plt.plot(x,2*x+1,'b-')
#점의 평균 x값y값으로 빨간선 찾기(보험용)
for i in range(-20,20):
 aa=0
 ab=0
 m=0
 y=np.arange(-20.00,20.00,1)
 k=randint(-10,10)
 v=2*i+1+k
 plt.scatter(i,v,c='black')
 aa+=i
 ab+=v 
 m+=1




plt.plot(x,2*x+1,'b-')
plt.xlabel('x')
plt.ylabel('y')

plt.plot(x,(ab/aa)*x+3,'r-')

plt.title("Sample Visualization")
plt.show()

# %%
#최솟값을 찾으려면

#미지수 2개를 찾기(기울기,y절편)
#그러려면
